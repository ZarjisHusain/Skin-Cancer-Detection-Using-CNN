# %%
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import os, cv2
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
from sklearn.metrics import confusion_matrix , classification_report
from keras.utils import to_categorical
from PIL import Image

# %%
data = pd.read_csv('skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005
# 0        192        153        193        195        155        192  \
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344
# 0        197        154        185        202  ...        173        124  \
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350
# 0        138        183        147        166        185        154  \
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
#After review infomations of the data, I knew 'dx' column being diseases's name.
classes = {4: ('nv', ' melanocytic nevi'), 
           6: ('mel', 'melanoma'), 
           2 :('bkl', 'benign keratosis-like lesions'), 
           1:('bcc' , ' basal cell carcinoma'), 
           5: ('vasc', ' pyogenic granulomas and hemorrhage'), 
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),  
           3: ('df', 'dermatofibroma')}

# %%
#I realize the last column being the label
y = data['label']
x = data.drop(columns = ['label'])
#get x_train ,y_train
x.shape
# Out:
# (10015, 2352)

# %%
oversample = RandomOverSampler()
x,y  = oversample.fit_resample(x,y)
x = np.array(x).reshape(-1,28,28,3)
print('Shape of Data :',x.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
#model_1, Because Input shape just have 28x28, so we need simple model
model = Sequential()
model.add(Conv2D(16, kernel_size = (3,3), input_shape = (28, 28, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model.add(Conv2D(64, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model.add(Conv2D(128, kernel_size = (3,3), activation = 'relu', padding = 'same'))
model.add(MaxPool2D(pool_size = (2,2), padding = 'same'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        4640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 32)        9248
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 64)                73792
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 182,791
# Trainable params: 182,791
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes = True, show_dtype = True, show_layer_names = True, rankdir="TB", expand_nested = True, dpi = 100) # ,to_file='model.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
Checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                                  monitor='val_loss', mode='max',
                                                 verbose=0)
File = 'SkinDiseases'
callback = [Checkpoint, 
             tf.keras.callbacks.EarlyStopping(patience = 5, monitor= "val_accuracy",verbose=1),
             tf.keras.callbacks.TensorBoard(log_dir = "logs/{}".format(File))]

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer = 'adam',
              metrics = ['accuracy'])
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 50,
                    callbacks=[callback])
# Out:
# Epoch 1/50
# 235/235 [==============================] - 9s 13ms/step - loss: 1.6644 - accuracy: 0.4517 - val_loss: 1.0668 - val_accuracy: 0.6063
# Epoch 2/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.8445 - accuracy: 0.6838 - val_loss: 0.6920 - val_accuracy: 0.7385
# Epoch 3/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.5646 - accuracy: 0.7938 - val_loss: 0.5652 - val_accuracy: 0.7935
# Epoch 4/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4159 - accuracy: 0.8507 - val_loss: 0.3885 - val_accuracy: 0.8603
# Epoch 5/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2751 - accuracy: 0.9035 - val_loss: 0.2815 - val_accuracy: 0.8996
# Epoch 6/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2034 - accuracy: 0.9281 - val_loss: 0.2800 - val_accuracy: 0.9064
# Epoch 7/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1698 - accuracy: 0.9400 - val_loss: 0.2479 - val_accuracy: 0.9160
# Epoch 8/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1273 - accuracy: 0.9562 - val_loss: 0.1537 - val_accuracy: 0.9494
# Epoch 9/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1317 - accuracy: 0.9533 - val_loss: 0.2205 - val_accuracy: 0.9294
# Epoch 10/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1157 - accuracy: 0.9581 - val_loss: 0.1938 - val_accuracy: 0.9370
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1025 - accuracy: 0.9637 - val_loss: 0.1696 - val_accuracy: 0.9458
# Epoch 12/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0906 - accuracy: 0.9679 - val_loss: 0.1339 - val_accuracy: 0.9567
# Epoch 13/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0509 - accuracy: 0.9822 - val_loss: 0.2436 - val_accuracy: 0.9313
# Epoch 14/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1427 - accuracy: 0.9518 - val_loss: 0.2566 - val_accuracy: 0.9152
# Epoch 15/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0634 - accuracy: 0.9779 - val_loss: 0.1334 - val_accuracy: 0.9640
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0519 - accuracy: 0.9824 - val_loss: 0.1255 - val_accuracy: 0.9672
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0568 - accuracy: 0.9809 - val_loss: 0.2312 - val_accuracy: 0.9324
# Epoch 18/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0802 - accuracy: 0.9719 - val_loss: 0.1803 - val_accuracy: 0.9551
# Epoch 19/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0488 - accuracy: 0.9835 - val_loss: 0.2246 - val_accuracy: 0.9490
# Epoch 20/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1041 - accuracy: 0.9658 - val_loss: 0.1337 - val_accuracy: 0.9619
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.1786 - val_accuracy: 0.9586
# Epoch 21: early stopping
